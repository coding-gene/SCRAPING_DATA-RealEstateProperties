# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'index_apartments.csv')
df.sort_values(by='Location', inplace=True)
df.head(5)
# Out:
#         Id                                              Title  \
# 86      91                                Stan Slavonski Brod
# 721    758                        Trosobni stan u Zatonu 96m2
# 658    691                             Stan Dubrovnik Šipčine
# 185    191                    Studio apartman Dubrovnik Lapad
# 1205  1268  Kuća u okolici Dubrovnika(vrbica),parking uklj...
#
#                     Location  PriceEuro  PriceKuna  Area  CijenaKvadratEuro  \
# 86          Brodsko-posavska        199       1500    32                  6
# 721   Dubrovačko-neretvanska        532       4000    96                  5
# 658   Dubrovačko-neretvanska        332       2500    45                  7
# 185   Dubrovačko-neretvanska        399       3000    30                 13
# 1205  Dubrovačko-neretvanska        372       2800    45                  8
#
#       CijenaKvadratKuna               Posted  \
# 86                   46  Objava  16.12.2021.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1297 entries, 86 to 1099
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 1297 non-null   int64
#  1   Title              1297 non-null   object
#  2   Location           1297 non-null   object
#  3   PriceEuro          1297 non-null   int64
#  4   PriceKuna          1297 non-null   int64
#  5   Area               1297 non-null   int64
#  6   CijenaKvadratEuro  1297 non-null   int64
#  7   CijenaKvadratKuna  1297 non-null   int64
#  8   Posted             1297 non-null   object
#  9   Link               1297 non-null   object
#  10  Photo              1297 non-null   object
# dtypes: int64(6), object(5)
# memory usage: 121.6+ KB

# %%
df.isnull().sum()
# Out:
# Id                   0
# Title                0
# Location             0
# PriceEuro            0
# PriceKuna            0
# Area                 0
# CijenaKvadratEuro    0
# CijenaKvadratKuna    0
# Posted               0
# Link                 0
# Photo                0
# dtype: int64

# %%
df.describe()
# Out:
#                 Id    PriceEuro     PriceKuna         Area  CijenaKvadratEuro  \
# count  1297.000000  1297.000000   1297.000000  1297.000000        1297.000000
# mean    681.665382   571.413261   4296.471858    64.260601           8.851966
# std     394.908380   295.342319   2220.804803    27.800379           3.690116
# min       1.000000   100.000000    752.000000    15.000000           0.000000
# 25%     341.000000   399.000000   3000.000000    45.000000           7.000000
# 50%     681.000000   500.000000   3760.000000    60.000000           8.000000
# 75%    1022.000000   650.000000   4888.000000    79.000000          11.000000
# max    1368.000000  2000.000000  15040.000000   230.000000          76.000000
#
#        CijenaKvadratKuna
# count        1297.000000
# mean           69.303778
# std            27.505223
# min             5.000000
# 25%            54.000000
# 50%            67.000000
# 75%            82.000000
# max           570.000000

# %%
df.memory_usage(deep=True)
# Out:
# Index                 10376
# Id                    10376
# Title                184565
# Location              94640
# PriceEuro             10376
# PriceKuna             10376
# Area                  10376
# CijenaKvadratEuro     10376
# CijenaKvadratKuna     10376
# Posted                98647
# Link                 180575
# Photo                246408
# dtype: int64

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(16, 8)})
import matplotlib.pyplot as plt

# %%
sns.countplot(x=df['Location'])
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['Location'], y=df['CijenaKvadratEuro'])
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.regplot(x=df['Area'], y=df['CijenaKvadratEuro'], scatter=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.lmplot(x="Area", y="CijenaKvadratEuro", col='Location', data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(x=df['Area'], y=df['CijenaKvadratEuro'], hue=df['Location'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                          Id  PriceEuro  PriceKuna      Area  \
# Id                 1.000000   0.032521   0.032348  0.064497
# PriceEuro          0.032521   1.000000   0.999998  0.697657
# PriceKuna          0.032348   0.999998   1.000000  0.697634
# Area               0.064497   0.697657   0.697634  1.000000
# CijenaKvadratEuro -0.022985   0.430054   0.429956 -0.243771
# CijenaKvadratKuna -0.026669   0.431326   0.431239 -0.243984
#
#                    CijenaKvadratEuro  CijenaKvadratKuna
# Id                         -0.022985          -0.026669
# PriceEuro                   0.430054           0.431326
# PriceKuna                   0.429956           0.431239
# Area                       -0.243771          -0.243984
# CijenaKvadratEuro           1.000000           0.996736
# CijenaKvadratKuna           0.996736           1.000000

# %%
sns.heatmap(correlation_matrix)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df['PriceEuro'])
plt.show
# Out:
# C:\Users\Ivan\.virtualenvs\realEstateProperties-F6cuYW1f\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.jointplot(x=df['PriceEuro'], y=df['Area'])

# %%
sns.jointplot(x=df['PriceEuro'], y=df['Area'], kind='kde', space=0.2, color=tableau_20[10])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(df, hue='Location')
plt.show()
