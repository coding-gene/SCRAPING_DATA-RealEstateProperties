# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'index_apartments.csv')
df.sort_values(by='Location', inplace=True)
df.head(5)
# Out:
#       Id                                   Title                Location  \
# 179  180  Stan Slavonski Brod Naselje Mikrorajon        Brodsko-posavska
# 48    49                     Stan Slavonski Brod        Brodsko-posavska
# 174  175         Studio apartman Dubrovnik Lapad  Dubrovačko-neretvanska
# 640  641                     Stan Dubrovnik Gruž  Dubrovačko-neretvanska
# 770  771             Trosobni stan u Zatonu 96m2  Dubrovačko-neretvanska
#
#      PriceEuro  PriceKuna  Area  CijenaKvadratEuro  CijenaKvadratKuna  \
# 179          1          7    36               0.03               0.19
# 48         199       1500    32               6.22              46.88
# 174        399       3000    30              13.30             100.00
# 640        293       2200    36               8.14              61.11
# 770        532       4000    96               5.54              41.67
#
#                   Posted                                               Link  \
# 179  Objava  14.12.2021.  https://www.index.hr/oglasi/stan-slavonski-bro...
# 48   Objava  16.12.2021.  https://www.index.hr/oglasi/stan-slavonski-bro...
# 174  Objava  14.12.2021.  https://www.index.hr/oglasi/studio-apartman-du...
# 640  Objava  03.12.2021.  https://www.index.hr/oglasi/stan-dubrovnik-gru...
# 770  Objava  01.12.2021.  https://www.index.hr/oglasi/trosobni-stan-u-za...
#
#                                                  Photo
# 179  https://www.index.hr/oglasi/UserDocsImages/ogl...
# 48   https://www.index.hr/oglasi/UserDocsImages/ogl...
# 174  https://www.index.hr/oglasi/UserDocsImages/ogl...
# 640  https://www.index.hr/oglasi/UserDocsImages/ogl...
# 770  https://www.index.hr/oglasi/UserDocsImages/ogl...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 879 entries, 179 to 102
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 879 non-null    int64
#  1   Title              879 non-null    object
#  2   Location           879 non-null    object
#  3   PriceEuro          879 non-null    int64
#  4   PriceKuna          879 non-null    int64
#  5   Area               879 non-null    int64
#  6   CijenaKvadratEuro  879 non-null    float64
#  7   CijenaKvadratKuna  879 non-null    float64
#  8   Posted             879 non-null    object
#  9   Link               879 non-null    object
#  10  Photo              879 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 82.4+ KB

# %%
df.isnull().sum()
# Out:
# Id                   0
# Title                0
# Location             0
# PriceEuro            0
# PriceKuna            0
# Area                 0
# CijenaKvadratEuro    0
# CijenaKvadratKuna    0
# Posted               0
# Link                 0
# Photo                0
# dtype: int64

# %%
df.describe()
# Out:
#               Id    PriceEuro     PriceKuna        Area  CijenaKvadratEuro  \
# count  879.00000   879.000000    879.000000  879.000000             879.00
# mean   440.00000   577.868032   4345.386803   62.508532                inf
# std    253.88974   381.891782   2871.674912   31.524581                NaN
# min      1.00000     0.000000      0.000000    0.000000               0.00
# 25%    220.50000   399.000000   3000.000000   44.000000               7.27
# 50%    440.00000   500.000000   3760.000000   57.000000               9.15
# 75%    659.50000   650.000000   4888.000000   75.000000              11.40
# max    879.00000  3000.000000  22559.000000  230.000000                inf
#
#        CijenaKvadratKuna
# count             879.00
# mean                 inf
# std                  NaN
# min                 0.00
# 25%                54.70
# 50%                68.75
# 75%                85.72
# max                  inf

# %%
df.memory_usage(deep=True)
# Out:
# Index                  7032
# Id                     7032
# Title                124536
# Location              64669
# PriceEuro              7032
# PriceKuna              7032
# Area                   7032
# CijenaKvadratEuro      7032
# CijenaKvadratKuna      7032
# Posted                66887
# Link                 122381
# Photo                167335
# dtype: int64

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(16, 8)})
import matplotlib.pyplot as plt

# %%
sns.barplot(x=df['Location'], y=df['PriceEuro'])
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['Location'], y=df['CijenaKvadratEuro'])
plt.xticks(rotation=90)
plt.show
# Out:
# C:\Users\Ivan\.virtualenvs\realEstateProperties-F6cuYW1f\lib\site-packages\numpy\lib\function_base.py:4009: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['Location'], y=df['Area'])
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.jointplot(x=df['PriceEuro'], y=df['Area'])

# %%
sns.jointplot(x=df['PriceEuro'], y=df['Area'], kind='hex')

# %%
sns.jointplot(x=df['PriceEuro'], y=df['Area'], kind='kde')

# %%
ax = sns.stripplot(x=df['Location'], y=df['PriceEuro'])
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Brodsko-posavska'),
#  Text(1, 0, 'Dubrovačko-neretvanska'),
#  Text(2, 0, 'Grad Zagreb'),
#  Text(3, 0, 'Istarska'),
#  Text(4, 0, 'Karlovačka'),
#  Text(5, 0, 'Krapinsko-zagorska'),
#  Text(6, 0, 'Međimurska'),
#  Text(7, 0, 'Osječko-baranjska'),
#  Text(8, 0, 'Požeško-slavonska'),
#  Text(9, 0, 'Primorsko-goranska'),
#  Text(10, 0, 'Sisačko-moslavačka'),
#  Text(11, 0, 'Splitsko-dalmatinska'),
#  Text(12, 0, 'Varaždinska'),
#  Text(13, 0, 'Vukovarsko-srijemska'),
#  Text(14, 0, 'Zadarska'),
#  Text(15, 0, 'Zagrebačka'),
#  Text(16, 0, 'Šibensko-kninska')]
